# %%
import pandas as pd
df = pd.read_csv("ead_DE-1a_4273.csv")
df
# Out:
#      persname.authfilenumber                   persname.content  \
# 0                  118770950       Walden, Herwarth (1878-1941)
# 1                  118770950       Walden, Herwarth (1878-1941)
# 2                  118770950       Walden, Herwarth (1878-1941)
# 3                  118846124  Adrian-Nilsson, Gösta (1884-1965)
# 4                  118770950       Walden, Herwarth (1878-1941)
# ...                      ...                                ...
# 8433               118636278             Zech, Paul (1881-1946)
# 8434               118770950       Walden, Herwarth (1878-1941)
# 8435               118770950       Walden, Herwarth (1878-1941)
# 8436               118637479          Zweig, Stefan (1881-1942)
# 8437               118770950       Walden, Herwarth (1878-1941)
#
#      persname.encodinganalog        persname.normal    persname.role  \
# 0            DE-611-PS-99565       Walden, Herwarth  Bestandsbildner
# ...

# %%
pwd
# Out:
# '/home_ext/PK/b-kj102/Dokumente/ZBIW_datalib_Projekt_Kalliope'

# %%
import pandas as pd
df = pd.read_csv("ead_DE-1a_4273_persname.csv")
df
# Out:
#      persname.authfilenumber                   persname.content  \
# 0                  118770950       Walden, Herwarth (1878-1941)
# 1                  118770950       Walden, Herwarth (1878-1941)
# 2                  118770950       Walden, Herwarth (1878-1941)
# 3                  118846124  Adrian-Nilsson, Gösta (1884-1965)
# 4                  118770950       Walden, Herwarth (1878-1941)
# ...                      ...                                ...
# 8433               118636278             Zech, Paul (1881-1946)
# 8434               118770950       Walden, Herwarth (1878-1941)
# 8435               118770950       Walden, Herwarth (1878-1941)
# 8436               118637479          Zweig, Stefan (1881-1942)
# 8437               118770950       Walden, Herwarth (1878-1941)
#
#      persname.encodinganalog        persname.normal    persname.role  \
# 0            DE-611-PS-99565       Walden, Herwarth  Bestandsbildner
# ...

# %%
import pandas as pd
df = pd.read_csv("ead_test.csv")
df
# Out:
#                     1 "Adler          Jankel (1895-1949)"
# 0         71 "Adrian-Nilsson           Gösta (1884-1965)"
# 1                    1 "Alin                Hans (1893-)"
# 2              16 "Altenberg           Peter (1859-1919)"
# 3                34 "Ansorge          Conrad (1862-1930)"
# 4                 1 "Ansorge         Joachim (1893-1947)"
# ..                       ...                          ...
# 428               1 "Wüllner          Ludwig (1858-1938)"
# 429              1 "Wuthenow          Alwine (1820-1908)"
# 430                  8 "Zech            Paul (1881-1946)"
# 431             1 "Zemlinsky   Alexander von (1871-1942)"
# 432                 1 "Zweig          Stefan (1881-1942)"
#
# [433 rows x 2 columns]

# %%
import pandas as pd
df = pd.read_csv("ead_test2.csv")
df
# Out:
#                   1013423178                Flaum, Franz (1867-1917)  \
# 0                  101999275                 Bryk, Felix (1882-1957)
# 1                  104086424                  Aram, Kurt (1869-1934)
# 2                 1042243972         Kalischer, Siegmund (1880-1911)
# 3                  104820624                 Bildt, Paul (1885-1957)
# 4                 1057182249         Schennis, Friedrich (1852-1918)
# ..                       ...                                     ...
# 576                   746304  Melsted, Henning Finne von (1875-1953)
# 577                   746568       Engström, Per Leander (1886-1924)
# 578                   747485                                     NaN
# 579                   802027                          Holitzer, Carl
# 580  persname.authfilenumber                        persname.content
#
#             DE-611-PS-572606                Flaum, Franz      Verfasser  \
# ...
