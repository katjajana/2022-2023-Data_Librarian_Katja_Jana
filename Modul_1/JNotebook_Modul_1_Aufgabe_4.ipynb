# %%
import urllib.request
import pandas as pd

# %%
url = "https://data.seattle.gov/resource/tmmm-ytt6.csv?$where=checkoutyear=2018&$limit=10000"
checkout_file = "checkout.csv"
urllib.request.urlretrieve(url, checkout_file)
# Out:
# ('checkout.csv', <http.client.HTTPMessage at 0x7f5cb425f9d0>)

# %%
checkouts_df = pd.read_csv(checkout_file)

# %%
checkouts_df
# Out:
#      usageclass checkouttype materialtype  checkoutyear  checkoutmonth  \
# 0       Digital    OverDrive        EBOOK          2018              1
# 1       Digital       Hoopla   TELEVISION          2018              1
# 2      Physical      Horizon    SOUNDDISC          2018              1
# 3       Digital    OverDrive        EBOOK          2018              1
# 4       Digital    OverDrive        EBOOK          2018              1
# ...         ...          ...          ...           ...            ...
# 9995    Digital    OverDrive        EBOOK          2018              1
# 9996    Digital    OverDrive        EBOOK          2018              1
# 9997    Digital      Freegal         SONG          2018              1
# 9998   Physical      Horizon         BOOK          2018              1
# 9999   Physical      Horizon    SOUNDDISC          2018              1
#
#       checkouts                                              title  isbn  \
# ...

# %% [markdown]
# # Aufgaben Gruppe 1:
# 1. NaN bei Creator:
#  - Anzahl NaN bei Creator ist 1481: checkouts_df['creator'].isnull().sum()
# 2. Sortieren nach Publisher bzw. Veröffentlichungen pro Publisher zählen und Balkendiagramm der 10 häufigsten Publisher:
#  - checkouts_df.sort_values("publisher")
#  - checkouts_df["publisher"].value_counts().nlargest(n=10).plot(kind="bar") ;
# 3. Publication year: und Publikationen, die älter als hundert Jahre sind, in einem eigenen data frame speichern und darstellen:
#  - checkouts_aelter1922_df = checkouts_df[checkouts_df["publicationyear"] <= "1922"]

# %% [markdown]
# # Aufgabe 1:
# Zählen der NaN bei Creator

# %% [markdown]
# Bool'sche Abfrage, ob es in der Spalte creator NaN-Einträge gibt:

# %%
checkouts_df['creator'].isnull().values.any()
# Out:
# True

# %% [markdown]
# Abfrage der NaN Angaben bei creator in pro Zeile

# %%
checkouts_df['creator'].isnull()
# Out:
# 0       False
# 1        True
# 2       False
# 3       False
# 4       False
#         ...
# 9995    False
# 9996    False
# 9997     True
# 9998    False
# 9999    False
# Name: creator, Length: 10000, dtype: bool

# %% [markdown]
# Zählen der NaN Angaben bei Creator insgesamt:

# %%
checkouts_df['creator'].isnull().sum()
# Out:
# 1481

# %% [markdown]
# # Aufgabe 2

# %%
checkouts_df.sort_values("publisher")
# Out:
#      usageclass checkouttype materialtype  checkoutyear  checkoutmonth  \
# 2221   Physical      Horizon    VIDEODISC          2018              1
# 4929   Physical      Horizon         BOOK          2018              1
# 4290   Physical      Horizon    VIDEODISC          2018              1
# 4866   Physical      Horizon    VIDEODISC          2018              1
# 5325   Physical      Horizon    VIDEODISC          2018              1
# ...         ...          ...          ...           ...            ...
# 9969    Digital        Zinio     MAGAZINE          2018              1
# 9970    Digital      Freegal         SONG          2018              1
# 9971    Digital      Freegal         SONG          2018              1
# 9991    Digital      Freegal         SONG          2018              1
# 9997    Digital      Freegal         SONG          2018              1
#
#       checkouts                                              title  isbn  \
# ...

# %%
checkouts_df["publisher"].value_counts()
# Out:
# Random House, Inc.                                           439
# HarperCollins Publishers Inc.                                340
# Penguin Group (USA), Inc.                                    313
# Books on Tape                                                201
# Blackstone Audio, Inc.                                       192
#                                                             ...
# Knopf,                                                         1
# Severn House Publishers L,                                     1
# Grosset & Dunlap, an imprint of Penguin Group (USA) Inc.,      1
# Cleis,                                                         1
# HighBridge,                                                    1
# Name: publisher, Length: 2987, dtype: int64

# %%
# %matplotlib inline

# %% [markdown]
# Darstellung der 10 häufigsten Publisher

# %%
checkouts_df["publisher"].value_counts().nlargest(n=10).plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
checkouts_df["publisher"].value_counts().nlargest(n=10).plot(kind="barh")
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Aufgabe 3

# %% [markdown]
# Publicationyears einer bestimmten Periode ausgeben und Publikationen, die älter als 100 Jahre sind, in einem eigenen Dataframe speichern

# %%
checkouts_aelter1922_df = checkouts_df[checkouts_df["publicationyear"] <= "1922"]

# %%
checkouts_aelter1922_df
# Out:
#      usageclass checkouttype materialtype  checkoutyear  checkoutmonth  \
# 4989   Physical      Horizon         BOOK          2018              1
# 7621   Physical      Horizon         BOOK          2018              1
# 8414   Physical      Horizon         BOOK          2018              1
# 9556   Physical      Horizon         BOOK          2018              1
#
#       checkouts                                              title  isbn  \
# 4989          1  Jennie Gerhardt; a novel / by Theodore Dreiser...   NaN
# 7621          1            Morocco that was / by Walter B. Harris.   NaN
# 8414          1  Winter: from the Journal of Henry D. Thoreau. ...   NaN
# 9556          1  Myths and legends of the Pacific Northwest, es...   NaN
#
#                               creator  \
# 4989     Dreiser, Theodore, 1871-1945
# 7621        Harris, Walter, 1866-1933
# 8414  Thoreau, Henry David, 1817-1862
# 9556          Judson, Katharine Berry
#
# ...
